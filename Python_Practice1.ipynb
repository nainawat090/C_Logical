# %%
1. Given a list, find the smallest missing positive number.

2. Rearrange the list so that positive and negative numbers alternate.

3. Find all pairs whose sum is equal to k.

4. Find the element that appears more than n/2 times.

5. Move all even numbers before odd numbers (order doesn’t matter).

6. Find the maximum difference between two elements where the larger appears after the smaller.

7. Check if a list can be split into two parts with equal sum.

8. Find the longest increasing subsequence length (logic approach).

9. Replace each element with the product of all other elements.

10. Find the first repeating element with minimum index.

# %%
list = [3, 4, -1, 1]
s = set(list)
i = 1
while i in s:
    i += 1
print(i)
# Out:
# 2

# %%
list = [3, 4, -1, 1]
a=1
for i in list:
  if i==a:
    a+=1
  else:
    print()
# Out:
# 1
# 1
# 1

# %%
# Out:
# [1, -2, 3, -4, 5, -6]
